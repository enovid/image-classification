# %%
from fastai.vision import *

# %% [markdown]
# Use cpu to make predictions. (GPU is overkill)

# %%
defaults.device = torch.device('cpu')

# %% [markdown]
# The given path contains `export.pkl` - our pretrained model.

# %%
path = Path('data/brands')

# %%
learn = load_learner(path)

# %%
img = open_image(path/'coke'/'00000003.jpg')
img
# Out:
# Image (3, 396, 127)

# %%
pred_class, pred_idx, outputs = learn.predict(img)
pred_class
# Out:
# Category coke
